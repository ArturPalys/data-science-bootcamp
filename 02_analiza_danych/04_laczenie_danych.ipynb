# %% [markdown]
# <a href="https://colab.research.google.com/github/ArturPalys/data-science-bootcamp/blob/main/02_analiza_danych/04_laczenie_danych.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Pandas
# >Strona biblioteki: [https://pandas.pydata.org/](https://pandas.pydata.org/)
# >Dokumentacja: [https://pandas.pydata.org/pandas-docs/stable/](https://pandas.pydata.org/pandas-docs/stable/)
# >
# >Podstawowa biblioteka do analizy danych w języku Python.
# >
# >Aby zainstalować bibliotekę Pandas użyj polecenia poniżej:
# ```
# pip install pandas
# ```
# ### Spis treści:
# 1. [Import bibliotek](#a1)
# 2. [Wczytanie danych](#a2)
# 3. [Preprocessing](#a3)
# 4. [Konkatenacja danych](#a4)
# 5. [Metoda append()](#a5)

# %% [markdown]
# ### <a name='a1'></a> Import bibliotek

# %%
import pandas as pd
pd.__version__
# Out:
# '1.5.3'

# %% [markdown]
# ### <a name='a2'></a> Wczytanie danych

# %%
def fetch_financial_data(company='AMZN'):
    """
    This function fetch stock market quotations.
    """
    import pandas_datareader.data as web
    return web.DataReader(name=company, data_source='stooq')

apple = fetch_financial_data('AAPL')
amazon = fetch_financial_data('AMZN')
google = fetch_financial_data('GOOGL')
uber = fetch_financial_data('UBER')

# %%
uber.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1226 entries, 2024-03-22 to 2019-05-10
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    1226 non-null   float64
#  1   High    1226 non-null   float64
#  2   Low     1226 non-null   float64
#  3   Close   1226 non-null   float64
#  4   Volume  1226 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 57.5 KB

# %%
apple.head()
# Out:
#               Open     High     Low   Close       Volume
# Date
# 2024-03-22  171.76  173.050  170.06  172.28   71160138.0
# 2024-03-21  177.05  177.490  170.84  171.37  106181270.0
# 2024-03-20  175.72  178.670  175.09  178.67   53423102.0
# 2024-03-19  174.34  176.605  173.03  176.08   55215244.0
# 2024-03-18  175.57  177.710  173.52  173.72   75604184.0

# %%
amazon.head()
# Out:
#                Open     High     Low   Close    Volume
# Date
# 2024-03-22  177.752  179.255  176.75  178.87  27995378
# 2024-03-21  179.988  181.415  178.15  178.15  32824320
# 2024-03-20  176.140  178.530  174.64  178.15  29947150
# 2024-03-19  174.215  176.090  173.52  175.90  26880893
# 2024-03-18  175.800  176.690  174.28  174.48  31250688

# %% [markdown]
# będziemy łączyć dane które mają rózną ilość wierszy, ale mają wspólną cechę - index

# %% [markdown]
# ### <a name='a3'></a> Preprocessing

# %% [markdown]
# przetwarzanie nazwy naszych kolumn

# %%
apple.columns = ['apple_' + col.lower() for col in apple.columns]
amazon.columns = ['amazon_' + col.lower() for col in amazon.columns]
google.columns = ['google_' + col.lower() for col in google.columns]
uber.columns = ['uber_' + col.lower() for col in uber.columns]

# %%
apple.head()
# Out:
#             apple_open  apple_high  apple_low  apple_close  apple_volume
# Date
# 2024-03-22      171.76     173.050     170.06       172.28    71160138.0
# 2024-03-21      177.05     177.490     170.84       171.37   106181270.0
# 2024-03-20      175.72     178.670     175.09       178.67    53423102.0
# 2024-03-19      174.34     176.605     173.03       176.08    55215244.0
# 2024-03-18      175.57     177.710     173.52       173.72    75604184.0

# %%
amazon.head()
# Out:
#             amazon_open  amazon_high  amazon_low  amazon_close  amazon_volume
# Date
# 2024-03-22      177.752      179.255      176.75        178.87       27995378
# 2024-03-21      179.988      181.415      178.15        178.15       32824320
# 2024-03-20      176.140      178.530      174.64        178.15       29947150
# 2024-03-19      174.215      176.090      173.52        175.90       26880893
# 2024-03-18      175.800      176.690      174.28        174.48       31250688

# %% [markdown]
# ### <a name='a4'></a> Konkatenacja danych

# %%
df = pd.concat(objs=[apple, amazon, google, uber], axis=1 )
df
# Out:
#             apple_open  apple_high  apple_low  apple_close  apple_volume  \
# Date
# 2019-03-25     46.4104     46.5221    45.2191      45.7415  1.809331e+08
# 2019-03-26     46.4474     46.7405    44.7266      45.2659  2.055081e+08
# 2019-03-27     45.7435     45.9827    45.2071      45.6747  1.231733e+08
# 2019-03-28     45.7933     45.9369    45.4424      45.7365  8.575276e+07
# 2019-03-29     45.9997     46.0575    45.6926      46.0286  9.723962e+07
# ...                ...         ...        ...          ...           ...
# 2024-03-18    175.5700    177.7100   173.5200     173.7200  7.560418e+07
# 2024-03-19    174.3400    176.6050   173.0300     176.0800  5.521524e+07
# 2024-03-20    175.7200    178.6700   175.0900     178.6700  5.342310e+07
# 2024-03-21    177.0500    177.4900   170.8400     171.3700  1.061813e+08
# 2024-03-22    171.7600    173.0500   170.0600     172.2800  7.116014e+07
#
#             amazon_open  amazon_high  amazon_low  amazon_close  amazon_volume  \
# Date
# 2019-03-25      87.8895      89.1340     87.3750       88.7130      102076060
# 2019-03-26      89.6500      90.2885     88.6680       89.1880       97317600
# 2019-03-27      89.2065      89.3750     87.2840       88.2850       86496020
# 2019-03-28      88.5000      88.8965     87.6735       88.6710       60859160
# 2019-03-29      89.3290      89.6430     88.8315       89.0375       66415860
# ...                 ...          ...         ...           ...            ...
# 2024-03-18     175.8000     176.6900    174.2800      174.4800       31250688
# 2024-03-19     174.2150     176.0900    173.5200      175.9000       26880893
# 2024-03-20     176.1400     178.5300    174.6400      178.1500       29947150
# 2024-03-21     179.9880     181.4150    178.1500      178.1500       32824320
# 2024-03-22     177.7520     179.2550    176.7500      178.8700       27995378
#
#             google_open  google_high  google_low  google_close  google_volume  \
# Date
# 2019-03-25      59.9780      60.4720     59.5000       59.8690       27576980
# 2019-03-26      60.2595      60.3825     59.0880       59.4920       30752120
# 2019-03-27      59.5960      59.5960     58.2115       58.9005       29428040
# 2019-03-28      58.7750      58.8625     58.1715       58.6135       22402440
# 2019-03-29      59.0090      59.1985     58.3190       58.8445       30892300
# ...                 ...          ...         ...           ...            ...
# 2024-03-18     148.6100     152.1500    147.1700      147.6800       69273699
# 2024-03-19     148.1600     148.7913    146.0800      147.0300       24070435
# 2024-03-20     148.0000     148.8600    146.7350      148.7400       21311501
# 2024-03-21     149.4700     150.3700    146.9001      147.6000       24755597
# 2024-03-22     149.1200     151.5800    148.9800      150.7700       29211769
#
# max      81.940000    82.140000    80.790000    81.390000  3.642612e+08

# %%
pd.set_option('display.float_format', lambda x: f'{x:.2f}')

df.describe().T
# Out:
#                 count        mean         std         min         25%  \
# apple_open    1259.00      128.38       45.08       42.68       87.36
# apple_high    1259.00      129.83       45.44       43.28       88.82
# apple_low     1259.00      127.03       44.71       41.42       86.46
# apple_close   1259.00      128.50       45.09       42.15       87.70
# apple_volume  1259.00 99910932.05 53161935.07 24048344.00 65433831.00
# amazon_open   1259.00      131.41       30.73       82.08       98.54
# amazon_high   1259.00      133.00       30.99       83.48       99.99
# amazon_low    1259.00      129.72       30.42       81.30       97.31
# amazon_close  1259.00      131.39       30.67       81.82       98.70
# amazon_volume 1259.00 73135783.49 32614851.00 17626740.00 51631714.00
# google_open   1259.00      102.00       29.64       52.22       73.15
# google_high   1259.00      103.17       29.91       52.50       74.05
# google_low    1259.00      100.91       29.35       50.44       72.54
# google_close  1259.00      102.07       29.62       51.94       73.26
# google_volume 1259.00 33605991.23 14976356.05  9312760.00 24153115.50
# uber_open     1226.00       39.88       11.95       15.96       31.00
# uber_high     1226.00       40.66       12.05       17.80       31.70
# uber_low      1226.00       39.09       11.85       13.71       30.40
# uber_close    1226.00       39.89       11.96       14.82       31.06
# uber_volume   1226.00 25129294.26 18480180.48  3380003.00 15754203.25
#
#                       50%          75%          max
# apple_open         140.41       165.14       198.02
# apple_high         142.59       167.05       199.62
# apple_low          137.99       163.91       197.00
# apple_close        140.47       165.29       198.11
# apple_volume  86692180.44 117203418.39 434708544.96
# amazon_open        132.71       159.97       187.20
# amazon_high        133.87       161.66       188.65
# amazon_low         131.31       158.00       184.84
# amazon_close       132.70       159.81       186.57
# amazon_volume 64066940.00  85275340.50 311345660.00
# google_open        103.30       130.22       152.80
# google_high        104.97       131.88       153.78
# google_low         102.50       128.67       151.43
# google_close       104.18       129.89       153.51
# google_volume 29870669.00  37732094.50 133177100.00
# uber_open           37.41        46.34        81.94
# uber_high           38.02        47.24        82.14
# uber_low            36.70        45.75        80.79
# uber_close          37.31        46.41        81.39
# uber_volume   21193586.50  29423799.25 364261230.00

# %% [markdown]
# współczynniki korelacji poszczególnych zmiennych

# %%
df.corr()
# Out:
#                apple_open  apple_high  apple_low  apple_close  apple_volume  \
# apple_open           1.00        1.00       1.00         1.00         -0.50
# apple_high           1.00        1.00       1.00         1.00         -0.49
# apple_low            1.00        1.00       1.00         1.00         -0.51
# apple_close          1.00        1.00       1.00         1.00         -0.50
# apple_volume        -0.50       -0.49      -0.51        -0.50          1.00
# amazon_open          0.53        0.53       0.53         0.53         -0.12
# amazon_high          0.53        0.53       0.53         0.53         -0.12
# amazon_low           0.53        0.52       0.52         0.52         -0.13
# amazon_close         0.53        0.53       0.53         0.53         -0.13
# amazon_volume       -0.29       -0.28      -0.29        -0.29          0.61
# google_open          0.90        0.90       0.90         0.90         -0.50
# google_high          0.90        0.90       0.90         0.90         -0.50
# google_low           0.90        0.90       0.90         0.90         -0.51
# google_close         0.90        0.90       0.90         0.90         -0.50
# google_volume       -0.09       -0.09      -0.10        -0.10          0.45
# uber_open            0.33        0.32       0.33         0.33         -0.28
# uber_high            0.33        0.32       0.33         0.33         -0.27
# uber_low             0.34        0.33       0.34         0.33         -0.29
# uber_close           0.33        0.33       0.34         0.33         -0.28
# uber_volume          0.06        0.06       0.05         0.05          0.20
#
#                amazon_open  amazon_high  amazon_low  amazon_close  \
# apple_open            0.53         0.53        0.53          0.53
# apple_high            0.53         0.53        0.52          0.53
# apple_low             0.53         0.53        0.52          0.53
# apple_close           0.53         0.53        0.52          0.53
# apple_volume         -0.12        -0.12       -0.13         -0.13
# amazon_open           1.00         1.00        1.00          1.00
# amazon_high           1.00         1.00        1.00          1.00
# amazon_low            1.00         1.00        1.00          1.00
# amazon_close          1.00         1.00        1.00          1.00
# amazon_volume        -0.11        -0.09       -0.12         -0.11
# google_open           0.66         0.66        0.66          0.66
# google_high           0.66         0.66        0.66          0.66
# google_low            0.66         0.66        0.66          0.66
# google_close          0.66         0.66        0.66          0.66
# google_volume        -0.10        -0.09       -0.11         -0.11
# uber_open             0.59         0.59        0.60          0.59
# uber_high             0.60         0.59        0.61          0.60
# uber_low              0.59         0.58        0.60          0.59
# uber_close            0.59         0.59        0.60          0.60
# uber_volume          -0.03        -0.03       -0.04         -0.03
#
#                amazon_volume  google_open  google_high  google_low  \
# apple_open             -0.29         0.90         0.90        0.90
# apple_high             -0.28         0.90         0.90        0.90
# apple_low              -0.29         0.90         0.90        0.90
# apple_close            -0.29         0.90         0.90        0.90
# apple_volume            0.61        -0.50        -0.50       -0.51
# amazon_open            -0.11         0.66         0.66        0.66
# amazon_high            -0.09         0.66         0.66        0.66
# amazon_low             -0.12         0.66         0.66        0.66
# amazon_close           -0.11         0.66         0.66        0.66
# amazon_volume           1.00        -0.32        -0.31       -0.33
# google_open            -0.32         1.00         1.00        1.00
# google_high            -0.31         1.00         1.00        1.00
# google_low             -0.33         1.00         1.00        1.00
# google_close           -0.32         1.00         1.00        1.00
# google_volume           0.54        -0.14        -0.14       -0.16
# uber_open              -0.29         0.44         0.43        0.44
# uber_high              -0.29         0.44         0.43        0.44
# uber_low               -0.31         0.44         0.44        0.45
# uber_close             -0.30         0.44         0.43        0.44
# uber_volume             0.22         0.04         0.05        0.04
#
#                google_close  google_volume  uber_open  uber_high  uber_low  \
# apple_open             0.90          -0.09       0.33       0.33      0.34
# apple_high             0.90          -0.09       0.32       0.32      0.33
# apple_low              0.90          -0.10       0.33       0.33      0.34
# apple_close            0.90          -0.10       0.33       0.33      0.33
# apple_volume          -0.50           0.45      -0.28      -0.27     -0.29
# amazon_open            0.66          -0.10       0.59       0.60      0.59
# amazon_high            0.66          -0.09       0.59       0.59      0.58
# amazon_low             0.66          -0.11       0.60       0.61      0.60
# amazon_close           0.66          -0.11       0.59       0.60      0.59
# amazon_volume         -0.32           0.54      -0.29      -0.29     -0.31
# google_open            1.00          -0.14       0.44       0.44      0.44
# google_high            1.00          -0.14       0.43       0.43      0.44
# google_low             1.00          -0.16       0.44       0.44      0.45
# google_close           1.00          -0.15       0.44       0.44      0.44
# google_volume         -0.15           1.00      -0.15      -0.14     -0.16
# uber_open              0.44          -0.15       1.00       1.00      1.00
# uber_high              0.44          -0.14       1.00       1.00      1.00
# uber_low               0.44          -0.16       1.00       1.00      1.00
# uber_close             0.44          -0.15       1.00       1.00      1.00
# uber_volume            0.04           0.23      -0.13      -0.11     -0.14
#
#                uber_close  uber_volume
# apple_open           0.33         0.06
# apple_high           0.33         0.06
# apple_low            0.34         0.05
# apple_close          0.33         0.05
# apple_volume        -0.28         0.20
# amazon_open          0.59        -0.03
# amazon_high          0.59        -0.03
# amazon_low           0.60        -0.04
# amazon_close         0.60        -0.03
# amazon_volume       -0.30         0.22
# google_open          0.44         0.04
# google_high          0.43         0.05
# google_low           0.44         0.04
# google_close         0.44         0.04
# google_volume       -0.15         0.23
# uber_open            1.00        -0.13
# uber_high            1.00        -0.11
# uber_low             1.00        -0.14
# uber_close           1.00        -0.13
# uber_volume         -0.13         1.00

# %%
df.columns
# Out:
# Index(['apple_open', 'apple_high', 'apple_low', 'apple_close', 'apple_volume',
#        'amazon_open', 'amazon_high', 'amazon_low', 'amazon_close',
#        'amazon_volume', 'google_open', 'google_high', 'google_low',
#        'google_close', 'google_volume', 'uber_open', 'uber_high', 'uber_low',
#        'uber_close', 'uber_volume'],
#       dtype='object')

# %% [markdown]
# współczynniki korelacji tylko dla kolumn close

# %%
closes = [col for col in df.columns if col.endswith('close')]
closes
# Out:
# ['apple_close', 'amazon_close', 'google_close', 'uber_close']

# %% [markdown]
# które zmienne są ze sobą jak najbardziej skorelowane - 1

# %%
df[closes].corr()
# Out:
#               apple_close  amazon_close  google_close  uber_close
# apple_close          1.00          0.53          0.90        0.33
# amazon_close         0.53          1.00          0.66        0.60
# google_close         0.90          0.66          1.00        0.44
# uber_close           0.33          0.60          0.44        1.00

# %%
closes = [col for col in df.columns if col.endswith('close') or col.endswith('volume')]
closes
# Out:
# ['apple_close',
#  'apple_volume',
#  'amazon_close',
#  'amazon_volume',
#  'google_close',
#  'google_volume',
#  'uber_close',
#  'uber_volume']

# %%
df[closes].corr()
# Out:
#                apple_close  apple_volume  amazon_close  amazon_volume  \
# apple_close           1.00         -0.50          0.53          -0.29
# apple_volume         -0.50          1.00         -0.13           0.61
# amazon_close          0.53         -0.13          1.00          -0.11
# amazon_volume        -0.29          0.61         -0.11           1.00
# google_close          0.90         -0.50          0.66          -0.32
# google_volume        -0.10          0.45         -0.11           0.54
# uber_close            0.33         -0.28          0.60          -0.30
# uber_volume           0.05          0.20         -0.03           0.22
#
#                google_close  google_volume  uber_close  uber_volume
# apple_close            0.90          -0.10        0.33         0.05
# apple_volume          -0.50           0.45       -0.28         0.20
# amazon_close           0.66          -0.11        0.60        -0.03
# amazon_volume         -0.32           0.54       -0.30         0.22
# google_close           1.00          -0.15        0.44         0.04
# google_volume         -0.15           1.00       -0.15         0.23
# uber_close             0.44          -0.15        1.00        -0.13
# uber_volume            0.04           0.23       -0.13         1.00

# %% [markdown]
# ### <a name='a5'></a> Metoda append()

# %% [markdown]
# dorzucanie danych do obiektu DateFrame

# %%
uber.head()
# Out:
#             uber_open  uber_high  uber_low  uber_close  uber_volume
# Date
# 2024-03-22      79.80      80.45     79.20       80.23      8872408
# 2024-03-21      79.60      81.23     79.09       80.25     16191090
# 2024-03-20      77.09      78.95     76.75       78.64     11490382
# 2024-03-19      75.38      77.18     74.19       77.08     13035194
# 2024-03-18      77.00      77.00     73.66       75.70     18936712

# %%
uber_6 = uber[(uber.index.month == 6) & (uber.index.year == 2019)]
uber_6
# Out:
#             uber_open  uber_high  uber_low  uber_close  uber_volume
# Date
# 2019-06-28      45.10      47.08     45.08       46.38     28657002
# 2019-06-27      43.35      45.30     43.20       45.13     20155079
# 2019-06-26      43.25      43.40     42.36       42.50      8109056
# 2019-06-25      43.28      43.79     42.44       43.09      5755107
# 2019-06-24      44.00      44.07     42.82       43.09      5985052
# 2019-06-21      43.85      44.14     43.38       44.00      4973987
# 2019-06-20      45.03      45.29     43.51       43.86      9567367
# 2019-06-19      44.46      45.50     43.95       44.86     10331520
# 2019-06-18      44.30      44.89     43.75       43.86      7313602
# 2019-06-17      43.28      44.08     42.93       43.78      6557589
# 2019-06-14      44.75      44.80     43.11       43.23      7902223
# 2019-06-13      43.05      44.35     42.80       44.31     10178935
# 2019-06-12      42.52      42.65     41.71       42.17      5965250
# 2019-06-11      43.22      43.65     41.80       42.45      9095044
# 2019-06-10      44.02      44.59     42.53       42.61     11618701
# 2019-06-07      44.92      45.67     44.13       44.16     12654670
# 2019-06-06      45.00      45.75     44.28       44.92     16403691
# 2019-06-05      42.87      45.66     42.50       45.00     28609604
# 2019-06-04      42.56      42.88     40.70       42.75     23432141
# 2019-06-03      40.74      41.85     40.24       41.25     16605261

# %%
uber_7 = uber[(uber.index.month == 7) & (uber.index.year == 2019)]
uber_7
# Out:
#             uber_open  uber_high  uber_low  uber_close  uber_volume
# Date
# 2019-07-31      42.60      42.98     41.84       42.14      5970774
# 2019-07-30      43.71      43.74     42.49       42.59      7686342
# 2019-07-29      45.00      45.63     43.12       43.88      8652204
# 2019-07-26      43.42      44.96     43.39       44.52      7598828
# 2019-07-25      43.72      43.96     43.21       43.40      4411991
# 2019-07-24      43.36      43.87     43.36       43.76      3775677
# 2019-07-23      43.75      44.31     43.11       43.36      5110090
# 2019-07-22      43.25      43.72     43.01       43.69      3822276
# 2019-07-19      43.90      44.09     43.16       43.18      4021018
# 2019-07-18      43.50      43.85     43.19       43.71      4123615
# 2019-07-17      44.06      44.35     43.52       43.62      5854149
# 2019-07-16      44.60      44.98     44.02       44.13      5613321
# 2019-07-15      44.20      44.70     43.97       44.53      5811160
# 2019-07-12      44.16      44.24     43.39       43.99      8760526
# 2019-07-11      44.10      44.29     43.31       43.99      8050856
# 2019-07-10      44.48      44.80     43.56       43.70      9746505
# 2019-07-09      43.18      44.23     42.98       44.20      5251564
